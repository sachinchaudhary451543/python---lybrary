# %% [markdown]
# # BAR PLOT

# %% [markdown]
# # we can give the label of data and title,coor,font size we can see all related codes in this code

# %% [markdown]
# # we can give the width between 0 to 1 to the bars

# %%
import matplotlib.pyplot as plt
x = ["python","c","c++","JAVA"]
y = [85,70,60,82]
plt.xlabel("Language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("S.TECH.ANALYSIS",fontsize=15)
c = ["y","b","m","g"]
plt.bar(x,y,color=c,width=0.2)
plt.show()
# Out:
#                                   NAME                 TOWER  \
# 0                   DEEPAK KUMAR SINGH  D-1207A
# 1                 DEVENDRA SINGH RAWAT  D-702
# 2                     RAKESH CHAUDHARY  F-1101
# 3                             ASHA RAM  D-1107
# 4                         OM PAL SINGH  B-1104
# ..                                 ...                   ...
# 442                     HARVINDER KAUR  V-024
# 443                    PRAKASH CHANDRA  V-026
# 444                        ROHIT ANAND  V-027
# 445         CHUNNILAL JAIRAM KANOUJIYA  V-028
# 446  PERUNGULAM BALASUBRAMANIAN SURESH  V-012A
#
#                                                    ADD  \
# 0    H.NO. 358,  IST FLOOR,  SECTOR-22A,  GURGAON N...
# 1
# 2    PLOT NO. 90,  SECTOR-3,  IMT MANESAR,GURGAON  ...
# 3    HOUSE NO. 77,   SECTOR -22/A                  ...
# 4    H. NO. 237  IIND FLOOR  MAY FIELD GARDEN   SEC...
# ..                                                 ...
# 442  FLAT NO. G-1,  ROYAL MANSION,  9-15-8,  CBM CO...
# 443  P.O-20375,AJMAN (UAE)                         ...
# 444  P.O BOX 371028,  DUBAI,U.A.E                  ...
# 445  P.O BOX 20375,  AJMAN,UAE.                    ...
# 446  PERUNGULAM BALASUBRAMANIAN SURESH, SECTION HEA...
#
#                                                 NUMBER  \
# 0                                           9873798401
# 1                                           9818220791
# 2                                           9810175341
# 3                                           9818664854
# 4                                           9891128190
# ..                                                 ...
# 442                                         9212339738
# 443                                        9.71505E+11
# 444  971-4-2990203                                 ...
# 445  971-50-5174748                                ...
# 446                                        97126743046
#
#                                               NUMBER.1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 442  011-42480180                                  ...
# 443
# 444
# 445
# 446                                        9.71508E+11
#
#                                              EMAIL ID
# 0    deepaksinghjadon@gmail.com                    ...
# 1                             devendra.rawat@gmail.com
# 2                                 sxrakesh25@gmail.com
# 3                                ashapuraini@gmail.com
# 4                           shivamlaminate@yahoo.co.in
# ..                                                 ...
# 442
# 443
# 444
# 445  watania2006@gmaol.com                         ...
# 446
#
# [447 rows x 6 columns]

# %% [markdown]
# # we can align the names of the bars at the edge or center for the bars

# %%
import matplotlib.pyplot as plt
x = ["python","c","c++","JAVA"]
y = [85,70,60,82]
plt.xlabel("Language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("S.TECH.ANALYSIS",fontsize=15)
c = ["y","b","m","g"]
plt.bar(x,y,color=c,width=0.2,align="edge")
plt.show()

# %% [markdown]
# # we can also give the borders to the bars also with the changing style of the border

# %%
import matplotlib.pyplot as plt
x = ["python","c","c++","JAVA"]
y = [85,70,60,82]
plt.xlabel("Language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("S.TECH.ANALYSIS",fontsize=15)
c = ["y","b","m","g"]
plt.bar(x,y,color=c,width=0.2,edgecolor="r",linewidth=4,linestyle=":")
plt.show()

# %% [markdown]
# # we can make fade the graph with the alpha

# %%
import matplotlib.pyplot as plt
x = ["python","c","c++","JAVA"]
y = [85,70,60,82]
plt.xlabel("Language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("S.TECH.ANALYSIS",fontsize=15)
c = ["y","b","m","g"]
plt.bar(x,y,color=c,width=0.2,alpha=0.4)
plt.show()

# %% [markdown]
# # we can give the label to the bar with the label="name" with plt.legend() parameter

# %%
import matplotlib.pyplot as plt
x = ["python","c","c++","JAVA"]
y = [85,70,60,82]
plt.xlabel("Language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("S.TECH.ANALYSIS",fontsize=15)
c = ["y","b","m","g"]
plt.bar(x,y,color=c,width=0.2,label="Prgramming_languages")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ["python","c","c++","Java"]
y = [85,80,65,82]
z = [20,30,40,50]

width  = 0.2
p = np.arange(len(x))
p1 = [j+width for j in p]

plt.xlabel("language",fontsize = 16)
plt.ylabel("No",fontsize = 16)
plt.title("Tech analysis",fontsize = 16)


plt.bar(p,y,width,color='r',label="popularity")
plt.bar(p1,z,width,color='y',label="popularity1")


plt.legend()
plt.show()

# %% [markdown]
# # we can show the names below the bars which is in the data and also we can rotate that [plt.xticks(p+width/2,x,rotation=20)]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = ["python","c","c++","Java"]
y = [85,80,65,82]
z = [20,30,40,50]

width = .2
p = np.arange(len(x))
p1 = [j+width for j in p]

plt.xlabel("languages",fontsize = 16)
plt.ylabel("No",fontsize = 16)
plt.title("Analysis")

plt.bar(p,y,width,color = ("r",'g',"b",'y'),label="popularity")
plt.bar(p1,z,width,color="b",label="popularity1")


plt.xticks(p+width/2,x,rotation=20)

plt.legend()
plt.show()
