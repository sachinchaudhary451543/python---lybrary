# %% [markdown]
# # ✅ Definition
# # A line plot in Seaborn is used to visualize the relationship between two continuous variables. It is ideal for time-series data, trends, and showing changes over an interval.
#
# # In Seaborn, the line plot function is:
# # seaborn.lineplot()
#
#
#
# # 🧪 Basic Syntax:
#
# # import seaborn as sns
# # import matplotlib.pyplot as plt
#
# # sns.lineplot(x=..., y=..., data=...)
# # plt.show()
#
# # seaborn works on data frame so we have to create or store the dataset in data frame to visualise -->
#
#
#
#
# # 📊 Example: Basic Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
import pandas as pd
data = pd.DataFrame({
    'day': [1, 2, 3, 4, 5],
    'sales': [100, 200, 150, 300, 250]
})

# Line plot
sns.lineplot(x='day', y='sales', data=data)
plt.title("Sales Over Days")
plt.show()

# %% [markdown]
# # 🧩 Common Parameters of sns.lineplot()
# # Parameter	Description
# # x	Column name for x-axis
# # y	Column name for y-axis
# # data	DataFrame source
# # hue	Separate lines by category
# # style	Different line styles per category
# # size	Vary line thickness
# # markers	Show markers on data points
# # dashes	Customize line dashes
# # palette	Set color scheme
# # ci	Confidence interval (default = 95). Use ci=None to disable
#
#
#
# # 🌈 Example: Multiple Lines by Category

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
data = sns.load_dataset("fmri")

# Line plot with hue and style
sns.lineplot(x="timepoint", y="signal", hue="event", style="event", data=data)
plt.title("FMRI Signal Over Time")
plt.show()

# %% [markdown]
# # 📌 Add Markers to Line Plot
#
# sns.lineplot(x="day", y="sales", data=data, marker="o")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
import pandas as pd
data = pd.DataFrame({
    'day': [1, 2, 3, 4, 5],
    'sales': [100, 200, 150, 300, 250]
})

# Line plot
sns.lineplot(x='day', y='sales', data=data,marker="o")
plt.title("Sales Over Days")
plt.show()

# %% [markdown]
# # 🎯 Disable Confidence Interval (CI)

# %%
data = pd.DataFrame({
    'day': [1, 2, 3, 4, 5],
    'sales': [100, 200, 150, 300, 250]
})

# Line plot
sns.lineplot(x='day', y='sales', data=data,marker="o",errorbar=None)
plt.title("Sales Over Days")
plt.show()

# %% [markdown]
# # costom dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_set = pd.DataFrame({
    "data_1":[1,2,3,4,5,6,7,8],"data_2":[11,33,22,55,44,77,66,88]
})

sns.lineplot(x="data_1",y="data_2",data=data_set,marker="o")


plt.show()

# %% [markdown]
# # sns.load_dataset(data_name)--- we tooke this from the github to get the random data, search on gogle seaborn data and we will get the github link for the data set adn put the name of the file to get the data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
y1 = sns.load_dataset("fmri")


y1
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %% [markdown]
# # uper vale syntex me hamne variable ko direct cal kiya jisse hame data show ho gya and ab ham uski headings bhi dekh sakte hai

# %%
sns.lineplot(x="signal",y="subject",data=y1,marker=">")
plt.show()

# %% [markdown]
# # hue--this parameter used to show the effective data comparative with in the plots and this willalso show the inbuilt legend

# %%
sns.lineplot(x="signal",y="subject",data=y1,hue="region")
plt.show()

# %% [markdown]
# # size--->this parameter can increase or decrease the size of the graph
# # style--->this parameter can change the style of the plots or barswe have to give the argument name from the hue legend names to change the style
# # palette--->this parameter can change the colors of teh bars also if we give the wrong argument then we will get all the color names in the error

# %%
sns.lineplot(x="signal",y="subject",data=y1,hue="region",size=50)
plt.show()

# %%
sns.lineplot(x="signal",y="subject",data=y1,hue="region",style="region")
plt.show()

# %%
sns.lineplot(x="signal",y="subject",data=y1,hue="region",palette='Accent')
plt.show()

# %% [markdown]
# # marker--->this parameter can make the corner of the plot bars with the diffrent shapes

# %%
sns.lineplot(x="signal",y="subject",data=y1,hue="region",markers=["o",">"])
plt.show()

# %% [markdown]
# # head--->this parameter is used to show the data costom means we have the 600 row but we wants to see 20 rows then sns.load_dataset("dataname").head(20)

# %%
y1= sns.load_dataset("fmri").head(20)
y1
# Out:
#    subject  timepoint event    region    signal
# 0      s13         18  stim  parietal -0.017552
# 1       s5         14  stim  parietal -0.080883
# 2      s12         18  stim  parietal -0.081033
# 3      s11         18  stim  parietal -0.046134
# 4      s10         18  stim  parietal -0.037970
# 5       s9         18  stim  parietal -0.103513
# 6       s8         18  stim  parietal -0.064408
# 7       s7         18  stim  parietal -0.060526
# 8       s6         18  stim  parietal -0.007029
# 9       s5         18  stim  parietal -0.040557
# 10      s4         18  stim  parietal -0.048812
# 11      s3         18  stim  parietal -0.047148
# 12      s2         18  stim  parietal -0.086623
# 13      s1         18  stim  parietal -0.046659
# 14      s0         18  stim  parietal -0.075570
# 15     s13         17  stim  parietal -0.008265
# 16     s12         17  stim  parietal -0.088512
# 17      s7          9  stim  parietal  0.058897
# 18     s10         17  stim  parietal -0.016847
# ...

# %%
sns.lineplot(x="timepoint",y="signal",data=y1,hue="event",marker=">")
plt.show()
